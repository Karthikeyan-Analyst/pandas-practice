# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthikeyan-Analyst/pandas-practice/blob/Python_practice/pandas_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a151283d-5e53-44e7-b350-f948639da47a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a151283d-5e53-44e7-b350-f948639da47a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
obesity_data = pd.read_csv('obesity_dataset_2000_rows.csv')
obesity_data.head(100)
# Out:
#     Gender  Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0   Female   27    1.46   133.5             no   no   1.4    1  Sometimes
# 1     Male   15    1.52   120.8             no  yes   2.4    2         no
# 2     Male   49    1.47    45.7             no   no   1.6    3         no
# 3     Male   24    1.85    99.7            yes   no   2.4    3     Always
# 4   Female   19    1.79   133.2            yes  yes   2.1    2  Sometimes
# ..     ...  ...     ...     ...            ...  ...   ...  ...        ...
# 95    Male   17    1.98   106.3            yes   no   2.9    2         no
# 96    Male   15    1.80   129.3             no  yes   3.0    1     Always
# 97  Female   50    1.48   107.1            yes   no   2.6    2  Sometimes
# 98  Female   51    1.91    54.3             no  yes   2.1    2  Sometimes
# 99  Female   55    1.72    96.0             no  yes   2.7    4         no
#
#    SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# ...

# %%
obesity_data.sample()
# Out:
#      Gender  Age  Height  Weight family_history FAVC  FCVC  NCP CAEC SMOKE  \
# 1983   Male   46     1.5    94.8             no   no   2.3    2   no    no
#
#       CH2O SCC  FAF  TUE        CALC      MTRANS         Obesity
# 1983   2.3  no  2.6  0.0  Frequently  Automobile  Obesity_Type_I

# %%
obesity_data.sample(10,random_state=19)
# Out:
#       Gender  Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 321     Male   43    1.77   134.7            yes  yes   1.2    3          no
# 1775    Male   24    1.60    81.2             no  yes   1.8    4   Sometimes
# 953     Male   35    1.89    82.3            yes   no   2.7    4      Always
# 529   Female   39    1.74   105.7             no  yes   2.7    4   Sometimes
# 1878  Female   52    1.92   111.3             no  yes   2.1    1          no
# 123     Male   58    1.55   103.7             no   no   3.0    3          no
# 1953    Male   16    1.61    90.4             no  yes   2.5    2  Frequently
# 856   Female   50    1.51    53.9            yes  yes   2.8    1  Frequently
# 613     Male   48    1.76    68.4            yes  yes   1.1    4          no
# 1938    Male   39    1.90   114.6            yes   no   2.1    1  Frequently
#
#      SMOKE  CH2O  SCC  FAF  TUE        CALC      MTRANS              Obesity
# ...

# %%
obesity_data.sample(2,random_state=9)
# Out:
#      Gender  Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 207  Female   34    1.49    68.8            yes   no   1.3    1  Frequently
# 756    Male   58    1.86    59.5             no   no   1.6    2   Sometimes
#
#     SMOKE  CH2O  SCC  FAF  TUE        CALC   MTRANS              Obesity
# 207   yes   1.5  yes  0.8  1.5  Frequently  Walking   Overweight_Level_I
# 756   yes   1.9   no  2.3  2.0  Frequently  Walking  Insufficient_Weight

# %%
obesity_data.columns.tolist()
# Out:
# ['Gender',
#  'Age',
#  'Height',
#  'Weight',
#  'family_history',
#  'FAVC',
#  'FCVC',
#  'NCP',
#  'CAEC',
#  'SMOKE',
#  'CH2O',
#  'SCC',
#  'FAF',
#  'TUE',
#  'CALC',
#  'MTRANS',
#  'Obesity']

# %%
obesity_data.shape
# Out:
# (2000, 17)

# %%
obesity_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          2000 non-null   object
#  1   Age             2000 non-null   int64
#  2   Height          2000 non-null   float64
#  3   Weight          2000 non-null   float64
#  4   family_history  2000 non-null   object
#  5   FAVC            2000 non-null   object
#  6   FCVC            2000 non-null   float64
#  7   NCP             2000 non-null   int64
#  8   CAEC            2000 non-null   object
#  9   SMOKE           2000 non-null   object
#  10  CH2O            2000 non-null   float64
#  11  SCC             2000 non-null   object
#  12  FAF             2000 non-null   float64
#  13  TUE             2000 non-null   float64
#  14  CALC            2000 non-null   object
#  15  MTRANS          2000 non-null   object
#  16  Obesity         2000 non-null   object
# ...

# %%
obesity_data.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     39.641000     1.719110    92.266600     1.988250     2.498500
# std      15.042848     0.157683    27.634548     0.582346     1.115625
# min      14.000000     1.450000    45.000000     1.000000     1.000000
# 25%      26.000000     1.580000    68.200000     1.500000     2.000000
# 50%      39.000000     1.710000    91.800000     2.000000     2.000000
# 75%      53.000000     1.860000   115.800000     2.500000     3.000000
# max      65.000000     2.000000   140.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2000.000000  2000.000000  2000.000000
# mean      1.997650     1.501050     1.006200
# std       0.572987     0.879392     0.582092
# min       1.000000     0.000000     0.000000
# 25%       1.500000     0.700000     0.500000
# 50%       2.000000     1.500000     1.000000
# ...

# %%
obesity_data.loc[0:10, 'Age':'Height']
# Out:
#     Age  Height
# 0    27    1.46
# 1    15    1.52
# 2    49    1.47
# 3    24    1.85
# 4    19    1.79
# 5    46    1.90
# 6    34    1.64
# 7    30    1.95
# 8    51    1.47
# 9    22    1.54
# 10   49    1.70

# %%
obesity_data.loc[:,]
# Out:
#       Gender  Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 0     Female   27    1.46   133.5             no   no   1.4    1   Sometimes
# 1       Male   15    1.52   120.8             no  yes   2.4    2          no
# 2       Male   49    1.47    45.7             no   no   1.6    3          no
# 3       Male   24    1.85    99.7            yes   no   2.4    3      Always
# 4     Female   19    1.79   133.2            yes  yes   2.1    2   Sometimes
# ...      ...  ...     ...     ...            ...  ...   ...  ...         ...
# 1995  Female   26    1.97   122.6            yes  yes   1.8    3  Frequently
# 1996    Male   42    1.79   108.8            yes   no   2.4    4   Sometimes
# 1997    Male   20    1.60    56.8            yes  yes   2.1    3          no
# 1998  Female   41    1.61    49.8             no   no   1.2    3      Always
# 1999  Female   33    1.87    75.8            yes  yes   3.0    1          no
#
# ...

# %%
obesity_data.loc[200:,'Gender':'Weight']
# Out:
#       Gender  Age  Height  Weight
# 200   Female   27    1.50    87.8
# 201     Male   52    1.86   110.5
# 202   Female   54    1.63   114.3
# 203   Female   32    1.80    95.5
# 204   Female   45    1.66   126.1
# ...      ...  ...     ...     ...
# 1995  Female   26    1.97   122.6
# 1996    Male   42    1.79   108.8
# 1997    Male   20    1.60    56.8
# 1998  Female   41    1.61    49.8
# 1999  Female   33    1.87    75.8
#
# [1800 rows x 4 columns]

# %%
obesity_data.iloc[2:5,2:5]
# Out:
#    Height  Weight family_history
# 2    1.47    45.7             no
# 3    1.85    99.7            yes
# 4    1.79   133.2            yes

# %% [markdown]
# Iloc using

# %%
obesity_data.iloc[:, 3:7]
# Out:
#       Weight family_history FAVC  FCVC
# 0      133.5             no   no   1.4
# 1      120.8             no  yes   2.4
# 2       45.7             no   no   1.6
# 3       99.7            yes   no   2.4
# 4      133.2            yes  yes   2.1
# ...      ...            ...  ...   ...
# 1995   122.6            yes  yes   1.8
# 1996   108.8            yes   no   2.4
# 1997    56.8            yes  yes   2.1
# 1998    49.8             no   no   1.2
# 1999    75.8            yes  yes   3.0
#
# [2000 rows x 4 columns]

# %%
obesity_data.iloc[[10,20,30],[1,3,6]]
# Out:
#     Age  Weight  FCVC
# 10   49    47.8   1.7
# 20   60    99.1   1.9
# 30   52    96.2   2.0

# %%
obesity_data.at[0,'Age']
# Out:
# np.int64(27)

# %%
obesity_data.iat[0,3]
# Out:
# np.float64(133.5)

# %%
obesity_data[['Age','Weight','FCVC']]
# Out:
#       Age  Weight  FCVC
# 0      27   133.5   1.4
# 1      15   120.8   2.4
# 2      49    45.7   1.6
# 3      24    99.7   2.4
# 4      19   133.2   2.1
# ...   ...     ...   ...
# 1995   26   122.6   1.8
# 1996   42   108.8   2.4
# 1997   20    56.8   2.1
# 1998   41    49.8   1.2
# 1999   33    75.8   3.0
#
# [2000 rows x 3 columns]

# %%
obesity_data.Age
# Out:
# 0       27
# 1       15
# 2       49
# 3       24
# 4       19
#         ..
# 1995    26
# 1996    42
# 1997    20
# 1998    41
# 1999    33
# Name: Age, Length: 2000, dtype: int64

# %%
obesity_data.head(20)
# Out:
#     Gender  Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 0   Female   27    1.46   133.5             no   no   1.4    1   Sometimes
# 1     Male   15    1.52   120.8             no  yes   2.4    2          no
# 2     Male   49    1.47    45.7             no   no   1.6    3          no
# 3     Male   24    1.85    99.7            yes   no   2.4    3      Always
# 4   Female   19    1.79   133.2            yes  yes   2.1    2   Sometimes
# 5     Male   46    1.90    67.6             no  yes   1.3    3   Sometimes
# 6   Female   34    1.64    80.9             no   no   2.8    1   Sometimes
# 7     Male   30    1.95   100.4            yes   no   2.6    1      Always
# 8   Female   51    1.47   124.9             no  yes   2.6    2          no
# 9   Female   22    1.54   139.2            yes   no   2.6    1      Always
# 10    Male   49    1.70    47.8            yes   no   1.7    3      Always
# ...

# %%
obesity_data.loc[obesity_data.Age > 30]
# Out:
#       Gender  Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 2       Male   49    1.47    45.7             no   no   1.6    3          no
# 5       Male   46    1.90    67.6             no  yes   1.3    3   Sometimes
# 6     Female   34    1.64    80.9             no   no   2.8    1   Sometimes
# 8     Female   51    1.47   124.9             no  yes   2.6    2          no
# 10      Male   49    1.70    47.8            yes   no   1.7    3      Always
# ...      ...  ...     ...     ...            ...  ...   ...  ...         ...
# 1989    Male   46    1.59    49.1             no  yes   2.7    1  Frequently
# 1990  Female   39    1.94    48.0             no   no   2.3    4          no
# 1996    Male   42    1.79   108.8            yes   no   2.4    4   Sometimes
# 1998  Female   41    1.61    49.8             no   no   1.2    3      Always
# 1999  Female   33    1.87    75.8            yes  yes   3.0    1          no
#
# ...

# %%
obesity_data.loc[obesity_data.Weight > 1.5]
# Out:
#       Gender  Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 0     Female   27    1.46   133.5             no   no   1.4    1   Sometimes
# 1       Male   15    1.52   120.8             no  yes   2.4    2          no
# 2       Male   49    1.47    45.7             no   no   1.6    3          no
# 3       Male   24    1.85    99.7            yes   no   2.4    3      Always
# 4     Female   19    1.79   133.2            yes  yes   2.1    2   Sometimes
# ...      ...  ...     ...     ...            ...  ...   ...  ...         ...
# 1995  Female   26    1.97   122.6            yes  yes   1.8    3  Frequently
# 1996    Male   42    1.79   108.8            yes   no   2.4    4   Sometimes
# 1997    Male   20    1.60    56.8            yes  yes   2.1    3          no
# 1998  Female   41    1.61    49.8             no   no   1.2    3      Always
# 1999  Female   33    1.87    75.8            yes  yes   3.0    1          no
#
# ...

# %%
obesity_data
# Out:
#       Gender  Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 0     Female   27    1.46   133.5             no   no   1.4    1   Sometimes
# 1       Male   15    1.52   120.8             no  yes   2.4    2          no
# 2       Male   49    1.47    45.7             no   no   1.6    3          no
# 3       Male   24    1.85    99.7            yes   no   2.4    3      Always
# 4     Female   19    1.79   133.2            yes  yes   2.1    2   Sometimes
# ...      ...  ...     ...     ...            ...  ...   ...  ...         ...
# 1995  Female   26    1.97   122.6            yes  yes   1.8    3  Frequently
# 1996    Male   42    1.79   108.8            yes   no   2.4    4   Sometimes
# 1997    Male   20    1.60    56.8            yes  yes   2.1    3          no
# 1998  Female   41    1.61    49.8             no   no   1.2    3      Always
# 1999  Female   33    1.87    75.8            yes  yes   3.0    1          no
#
# ...

# %%
obesity_data.loc[(obesity_data['Weight']>50) & (obesity_data['Obesity']=='Normal_Weight')]
# Out:
#       Gender  Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 13    Female   64    1.84   123.1             no   no   1.9    4   Sometimes
# 18      Male   54    1.53   124.9             no   no   2.9    4  Frequently
# 20    Female   60    1.54    99.1            yes  yes   1.9    1   Sometimes
# 21      Male   58    1.55    51.2             no  yes   1.4    3   Sometimes
# 35      Male   17    1.66    94.3             no   no   1.8    2   Sometimes
# ...      ...  ...     ...     ...            ...  ...   ...  ...         ...
# 1933  Female   55    1.89   134.0            yes   no   2.4    2          no
# 1967  Female   36    1.50   122.2            yes   no   1.9    4   Sometimes
# 1975  Female   52    1.57   109.3             no  yes   2.9    2   Sometimes
# 1982  Female   35    1.64    52.6             no  yes   1.9    1   Sometimes
# 1984    Male   35    1.78    72.2            yes  yes   1.8    1      Always
#
# ...

# %%
obesity_data.head(20)
# Out:
#     Gender  Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 0   Female   27    1.46   133.5             no   no   1.4    1   Sometimes
# 1     Male   15    1.52   120.8             no  yes   2.4    2          no
# 2     Male   49    1.47    45.7             no   no   1.6    3          no
# 3     Male   24    1.85    99.7            yes   no   2.4    3      Always
# 4   Female   19    1.79   133.2            yes  yes   2.1    2   Sometimes
# 5     Male   46    1.90    67.6             no  yes   1.3    3   Sometimes
# 6   Female   34    1.64    80.9             no   no   2.8    1   Sometimes
# 7     Male   30    1.95   100.4            yes   no   2.6    1      Always
# 8   Female   51    1.47   124.9             no  yes   2.6    2          no
# 9   Female   22    1.54   139.2            yes   no   2.6    1      Always
# 10    Male   49    1.70    47.8            yes   no   1.7    3      Always
# ...

# %%
obesity_data[obesity_data['Height']>1]
# Out:
#       Gender  Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 0     Female   27    1.46   133.5             no   no   1.4    1   Sometimes
# 1       Male   15    1.52   120.8             no  yes   2.4    2          no
# 2       Male   49    1.47    45.7             no   no   1.6    3          no
# 3       Male   24    1.85    99.7            yes   no   2.4    3      Always
# 4     Female   19    1.79   133.2            yes  yes   2.1    2   Sometimes
# ...      ...  ...     ...     ...            ...  ...   ...  ...         ...
# 1995  Female   26    1.97   122.6            yes  yes   1.8    3  Frequently
# 1996    Male   42    1.79   108.8            yes   no   2.4    4   Sometimes
# 1997    Male   20    1.60    56.8            yes  yes   2.1    3          no
# 1998  Female   41    1.61    49.8             no   no   1.2    3      Always
# 1999  Female   33    1.87    75.8            yes  yes   3.0    1          no
#
# ...

# %%
obesity_data.loc[(obesity_data['Height'])<2]
# Out:
#       Gender  Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 0     Female   27    1.46   133.5             no   no   1.4    1   Sometimes
# 1       Male   15    1.52   120.8             no  yes   2.4    2          no
# 2       Male   49    1.47    45.7             no   no   1.6    3          no
# 3       Male   24    1.85    99.7            yes   no   2.4    3      Always
# 4     Female   19    1.79   133.2            yes  yes   2.1    2   Sometimes
# ...      ...  ...     ...     ...            ...  ...   ...  ...         ...
# 1995  Female   26    1.97   122.6            yes  yes   1.8    3  Frequently
# 1996    Male   42    1.79   108.8            yes   no   2.4    4   Sometimes
# 1997    Male   20    1.60    56.8            yes  yes   2.1    3          no
# 1998  Female   41    1.61    49.8             no   no   1.2    3      Always
# 1999  Female   33    1.87    75.8            yes  yes   3.0    1          no
#
# ...

# %%
obesity_data
# Out:
#       Gender  Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 0     Female   27    1.46   133.5             no   no   1.4    1   Sometimes
# 1       Male   15    1.52   120.8             no  yes   2.4    2          no
# 2       Male   49    1.47    45.7             no   no   1.6    3          no
# 3       Male   24    1.85    99.7            yes   no   2.4    3      Always
# 4     Female   19    1.79   133.2            yes  yes   2.1    2   Sometimes
# ...      ...  ...     ...     ...            ...  ...   ...  ...         ...
# 1995  Female   26    1.97   122.6            yes  yes   1.8    3  Frequently
# 1996    Male   42    1.79   108.8            yes   no   2.4    4   Sometimes
# 1997    Male   20    1.60    56.8            yes  yes   2.1    3          no
# 1998  Female   41    1.61    49.8             no   no   1.2    3      Always
# 1999  Female   33    1.87    75.8            yes  yes   3.0    1          no
#
# ...

# %%
obesity_data.loc[:,'Age']
# Out:
# 0       27
# 1       15
# 2       49
# 3       24
# 4       19
#         ..
# 1995    26
# 1996    42
# 1997    20
# 1998    41
# 1999    33
# Name: Age, Length: 2000, dtype: int64

# %%
obesity_data.loc[(obesity_data['Age']>28) & (obesity_data['Gender']=='Male')].head(10)
# Out:
#    Gender  Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 2    Male   49    1.47    45.7             no   no   1.6    3          no
# 5    Male   46    1.90    67.6             no  yes   1.3    3   Sometimes
# 7    Male   30    1.95   100.4            yes   no   2.6    1      Always
# 10   Male   49    1.70    47.8            yes   no   1.7    3      Always
# 14   Male   53    1.81    85.6             no   no   1.1    4      Always
# 17   Male   33    1.58   112.2             no   no   1.5    4   Sometimes
# 18   Male   54    1.53   124.9             no   no   2.9    4  Frequently
# 19   Male   49    1.58   137.2            yes   no   1.3    2   Sometimes
# 21   Male   58    1.55    51.2             no  yes   1.4    3   Sometimes
# 22   Male   47    1.95   114.8            yes   no   1.7    2   Sometimes
#
#    SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 2     no   1.1   no  2.2  1.7  Frequently             Automobile
# ...

# %%
obesity_data.loc[(obesity_data['Gender']=='Female')]
# Out:
#       Gender  Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 0     Female   27    1.46   133.5             no   no   1.4    1   Sometimes
# 4     Female   19    1.79   133.2            yes  yes   2.1    2   Sometimes
# 6     Female   34    1.64    80.9             no   no   2.8    1   Sometimes
# 8     Female   51    1.47   124.9             no  yes   2.6    2          no
# 9     Female   22    1.54   139.2            yes   no   2.6    1      Always
# ...      ...  ...     ...     ...            ...  ...   ...  ...         ...
# 1993  Female   17    1.56   105.2            yes   no   2.7    2  Frequently
# 1994  Female   25    1.65   115.3             no   no   1.1    2   Sometimes
# 1995  Female   26    1.97   122.6            yes  yes   1.8    3  Frequently
# 1998  Female   41    1.61    49.8             no   no   1.2    3      Always
# 1999  Female   33    1.87    75.8            yes  yes   3.0    1          no
#
# ...

# %%
obesity_data.loc[(obesity_data['Gender']=='Female') & (obesity_data['Age']>25)]
# Out:
#       Gender  Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 0     Female   27    1.46   133.5             no   no   1.4    1   Sometimes
# 6     Female   34    1.64    80.9             no   no   2.8    1   Sometimes
# 8     Female   51    1.47   124.9             no  yes   2.6    2          no
# 11    Female   33    1.89    79.8            yes   no   2.5    2   Sometimes
# 12    Female   51    1.99   123.6             no   no   1.7    4   Sometimes
# ...      ...  ...     ...     ...            ...  ...   ...  ...         ...
# 1985  Female   26    1.95   107.4             no  yes   2.2    2  Frequently
# 1990  Female   39    1.94    48.0             no   no   2.3    4          no
# 1995  Female   26    1.97   122.6            yes  yes   1.8    3  Frequently
# 1998  Female   41    1.61    49.8             no   no   1.2    3      Always
# 1999  Female   33    1.87    75.8            yes  yes   3.0    1          no
#
# ...

# %%
obesity_data[obesity_data['Obesity'].str.startswith('Normal')]
# Out:
#       Gender  Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 13    Female   64    1.84   123.1             no   no   1.9    4   Sometimes
# 18      Male   54    1.53   124.9             no   no   2.9    4  Frequently
# 20    Female   60    1.54    99.1            yes  yes   1.9    1   Sometimes
# 21      Male   58    1.55    51.2             no  yes   1.4    3   Sometimes
# 35      Male   17    1.66    94.3             no   no   1.8    2   Sometimes
# ...      ...  ...     ...     ...            ...  ...   ...  ...         ...
# 1967  Female   36    1.50   122.2            yes   no   1.9    4   Sometimes
# 1975  Female   52    1.57   109.3             no  yes   2.9    2   Sometimes
# 1981  Female   55    1.59    48.3            yes   no   2.1    3   Sometimes
# 1982  Female   35    1.64    52.6             no  yes   1.9    1   Sometimes
# 1984    Male   35    1.78    72.2            yes  yes   1.8    1      Always
#
# ...

# %%
obesity_data[obesity_data['SMOKE'].str.contains('yes')]
# Out:
#       Gender  Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 0     Female   27    1.46   133.5             no   no   1.4    1   Sometimes
# 1       Male   15    1.52   120.8             no  yes   2.4    2          no
# 5       Male   46    1.90    67.6             no  yes   1.3    3   Sometimes
# 7       Male   30    1.95   100.4            yes   no   2.6    1      Always
# 9     Female   22    1.54   139.2            yes   no   2.6    1      Always
# ...      ...  ...     ...     ...            ...  ...   ...  ...         ...
# 1994  Female   25    1.65   115.3             no   no   1.1    2   Sometimes
# 1995  Female   26    1.97   122.6            yes  yes   1.8    3  Frequently
# 1996    Male   42    1.79   108.8            yes   no   2.4    4   Sometimes
# 1998  Female   41    1.61    49.8             no   no   1.2    3      Always
# 1999  Female   33    1.87    75.8            yes  yes   3.0    1          no
#
# ...

# %%
print(obesity_data.columns.tolist())
# Out:
# ['Gender', 'Age', 'Height', 'Weight', 'family_history', 'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE', 'CALC', 'MTRANS', 'Obesity']

# %%
obesity_data.columns = obesity_data.columns.str.strip()
obesity_data.head(2)
# Out:
#    Gender  Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female   27    1.46   133.5             no   no   1.4    1  Sometimes
# 1    Male   15    1.52   120.8             no  yes   2.4    2         no
#
#   SMOKE  CH2O  SCC  FAF  TUE       CALC     MTRANS              Obesity
# 0   yes   1.0   no  1.6  0.9         no  Motorbike  Overweight_Level_II
# 1   yes   2.3  yes  0.4  2.0  Sometimes       Bike  Insufficient_Weight

# %%
obesity_data.columns = obesity_data.columns.str.strip()
obesity_data = obesity_data.iloc[:, :-1]
obesity_data.head(2)
# Out:
#    Gender  Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female   27    1.46   133.5             no   no   1.4    1  Sometimes
# 1    Male   15    1.52   120.8             no  yes   2.4    2         no
#
#   SMOKE  CH2O  SCC  FAF  TUE       CALC     MTRANS
# 0   yes   1.0   no  1.6  0.9         no  Motorbike
# 1   yes   2.3  yes  0.4  2.0  Sometimes       Bike

# %%
obesity_data['Dummy']='dummy'

# %%
obesity_data.head(4)
# Out:
#    Gender  Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female   27    1.46   133.5             no   no   1.4    1  Sometimes
# 1    Male   15    1.52   120.8             no  yes   2.4    2         no
# 2    Male   49    1.47    45.7             no   no   1.6    3         no
# 3    Male   24    1.85    99.7            yes   no   2.4    3     Always
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC      MTRANS  Dummy
# 0   yes   1.0   no  1.6  0.9          no   Motorbike  dummy
# 1   yes   2.3  yes  0.4  2.0   Sometimes        Bike  dummy
# 2    no   1.1   no  2.2  1.7  Frequently  Automobile  dummy
# 3    no   1.5   no  0.8  0.9  Frequently        Bike  dummy

# %%
obesity_data=obesity_data.iloc[:,:-1]
obesity_data.head(3)
# Out:
#    Gender  Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female   27    1.46   133.5             no   no   1.4    1  Sometimes
# 1    Male   15    1.52   120.8             no  yes   2.4    2         no
# 2    Male   49    1.47    45.7             no   no   1.6    3         no
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC      MTRANS
# 0   yes   1.0   no  1.6  0.9          no   Motorbike
# 1   yes   2.3  yes  0.4  2.0   Sometimes        Bike
# 2    no   1.1   no  2.2  1.7  Frequently  Automobile

# %%
obesity_data.loc[0,'Age']=23
obesity_data.head(1)
# Out:
#    Gender  Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female   23    1.46   133.5             no   no   1.4    1  Sometimes
#
#   SMOKE  CH2O SCC  FAF  TUE CALC     MTRANS
# 0   yes   1.0  no  1.6  0.9   no  Motorbike

# %%
obesity_data.iloc[0,2]=24
obesity_data.head(1)
# Out:
#    Gender  Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female   23    24.0   133.5             no   no   1.4    1  Sometimes
#
#   SMOKE  CH2O SCC  FAF  TUE CALC     MTRANS
# 0   yes   1.0  no  1.6  0.9   no  Motorbike

# %%
obesity_data['Dummy']='dummy'
obesity_data.head(3)
# Out:
#    Gender  Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female   23   24.00   133.5             no   no   1.4    1  Sometimes
# 1    Male   15    1.52   120.8             no  yes   2.4    2         no
# 2    Male   49    1.47    45.7             no   no   1.6    3         no
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC      MTRANS  Dummy
# 0   yes   1.0   no  1.6  0.9          no   Motorbike  dummy
# 1   yes   2.3  yes  0.4  2.0   Sometimes        Bike  dummy
# 2    no   1.1   no  2.2  1.7  Frequently  Automobile  dummy

# %%
obesity_data=obesity_data.drop('Dummy',axis=1)
obesity_data.head(3)
# Out:
#    Gender  Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female   23   24.00   133.5             no   no   1.4    1  Sometimes
# 1    Male   15    1.52   120.8             no  yes   2.4    2         no
# 2    Male   49    1.47    45.7             no   no   1.6    3         no
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC      MTRANS
# 0   yes   1.0   no  1.6  0.9          no   Motorbike
# 1   yes   2.3  yes  0.4  2.0   Sometimes        Bike
# 2    no   1.1   no  2.2  1.7  Frequently  Automobile

# %%
import numpy as np

# %%
obesity_data['New_age_catgory']=np.where(obesity_data['Age']<25,'very young','not so young')
obesity_data.head(30)
# Out:
#     Gender  Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 0   Female   23   24.00   133.5             no   no   1.4    1   Sometimes
# 1     Male   15    1.52   120.8             no  yes   2.4    2          no
# 2     Male   49    1.47    45.7             no   no   1.6    3          no
# 3     Male   24    1.85    99.7            yes   no   2.4    3      Always
# 4   Female   19    1.79   133.2            yes  yes   2.1    2   Sometimes
# 5     Male   46    1.90    67.6             no  yes   1.3    3   Sometimes
# 6   Female   34    1.64    80.9             no   no   2.8    1   Sometimes
# 7     Male   30    1.95   100.4            yes   no   2.6    1      Always
# 8   Female   51    1.47   124.9             no  yes   2.6    2          no
# 9   Female   22    1.54   139.2            yes   no   2.6    1      Always
# 10    Male   49    1.70    47.8            yes   no   1.7    3      Always
# ...
