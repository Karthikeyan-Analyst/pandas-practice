# %%
import pandas as pd

# %%
vegas=['beetroot','carrot','tomato','kovakkai','coconut']

# %%
vegas_Series =pd.Series(vegas, index=['purple','orange','red','green','white'])
vegas_Series
# Out:
# purple    beetroot
# orange      carrot
# red         tomato
# green     kovakkai
# white      coconut
# dtype: object

# %%
vege_dict= {'red':'tomato','green':'kovakkai'}

# %%
vege_dict_series=pd.Series(vege_dict)
vege_dict_series
# Out:
# red        tomato
# green    kovakkai
# dtype: object

# %%
vege_dict_series['orange']='carrot'

# %%
vege_dict_series
# Out:
# red         tomato
# green     kovakkai
# orange      carrot
# dtype: object

# %%
vege_dict_series['white']='coconut'

# %%
vege_dict_series
# Out:
# red         tomato
# green     kovakkai
# orange      carrot
# white      coconut
# dtype: object

# %%
vege_dict_series.drop(['orange'],inplace=True)

# %%
vege_dict_series
# Out:
# red        tomato
# green    kovakkai
# white     coconut
# dtype: object

# %%
data = { 'vegetables': ['beetroot', 'carrot', 'redchilli', 'beans', 'coconut'],
       'color' : ['purple', 'orange', 'red', 'green', 'white'],
        'unit' : ['1kg', '1kg','1kg','1kg','1piece'],
       'min' : [25, 35, 33, 40, 'seventeen'],
       'max': [40, 45, 90, 45, 38],
       }

# %%
marketdf=pd.DataFrame(data,index=['a','b','c','d','e'])

# %%
marketdf
# Out:
#   vegetables   color    unit        min  max
# a   beetroot  purple     1kg         25   40
# b     carrot  orange     1kg         35   45
# c  redchilli     red     1kg         33   90
# d      beans   green     1kg         40   45
# e    coconut   white  1piece  seventeen   38

# %%
marketdf.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
marketdf['unit']
# Out:
# a       1kg
# b       1kg
# c       1kg
# d       1kg
# e    1piece
# Name: unit, dtype: object

# %%
marketdf.loc['a']
# Out:
# vegetables    beetroot
# color           purple
# unit               1kg
# min                 25
# max                 40
# Name: a, dtype: object

# %% [markdown]
# its shown as the a value (index in the given market data)

# %%
marketdf.loc['a','vegetables']
# Out:
# 'beetroot'

# %%
marketdf
# Out:
#   vegetables   color    unit        min  max
# a   beetroot  purple     1kg         25   40
# b     carrot  orange     1kg         35   45
# c  redchilli     red     1kg         33   90
# d      beans   green     1kg         40   45
# e    coconut   white  1piece  seventeen   38

# %%
marketdf.loc['f']={'vegetables':'pumpkin','color':'yellow','unit':'1piece','min':28,'max':33}
marketdf
# Out:
#   vegetables   color    unit        min  max
# a   beetroot  purple     1kg         25   40
# b     carrot  orange     1kg         35   45
# c  redchilli     red     1kg         33   90
# d      beans   green     1kg         40   45
# e    coconut   white  1piece  seventeen   38
# f    pumpkin  yellow  1piece         28   33

# %%
marketdf
# Out:
#   vegetables   color    unit        min  max
# a   beetroot  purple     1kg         25   40
# b     carrot  orange     1kg         35   45
# c  redchilli     red     1kg         33   90
# d      beans   green     1kg         40   45
# e    coconut   white  1piece  seventeen   38
# f    pumpkin  yellow  1piece         28   33

# %%
marketdf.loc['a','unit']
# Out:
# '1kg'

# %%
marketdf.loc['g']={'vegetables':'lemon','color':'yellow','unit':10,'min':28,'max':33}

# %%
marketdf
# Out:
#   vegetables   color    unit        min  max
# a   beetroot  purple     1kg         25   40
# b     carrot  orange     1kg         35   45
# c  redchilli     red     1kg         33   90
# d      beans   green     1kg         40   45
# e    coconut   white  1piece  seventeen   38
# f    pumpkin  yellow  1piece         28   33
# g      lemon  yellow      10         28   33

# %%
marketdf.isna()
# Out:
#    vegetables  color   unit    min    max
# a       False  False  False  False  False
# b       False  False  False  False  False
# c       False  False  False  False  False
# d       False  False  False  False  False
# e       False  False  False  False  False
# f       False  False  False  False  False
# g       False  False  False  False  False
